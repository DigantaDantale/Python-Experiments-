# %% [markdown]
# <a href="https://colab.research.google.com/github/DigantaDantale/Python-Experiments-/blob/main/Exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ATM:
    def __init__(self):
        self.pin = None
        self.balance = 0
        print("ATM system initialized!")
        self.menu()

    def menu(self):
        print("1. Set PIN")
        print("2. Change PIN")

atm1 = ATM()
# Out:
# ATM system initialized!
# 1. Set PIN
# 2. Change PIN

# %%
class Calculator:
    def add(self, a, b=0, c=0):
        return a + b + c

obj = Calculator()

print(obj.add(5))
print(obj.add(5, 10))
print(obj.add(5, 10, 15))
# Out:
# 5
# 15
# 30

# %%
class Student:
    def __init__(self, name=None, marks=None):
        self.name = name
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Marks:", self.marks)

s1 = Student()
s2 = Student("Rahul")
s3 = Student("Amit", 90)

s1.display()
s2.display()
s3.display()
# Out:
# Name: None
# Marks: None
# Name: Rahul
# Marks: None
# Name: Amit
# Marks: 90

# %%
class Bank:
    def __init__(self):
        self.__balance = 1000   # private variable

    def deposit(self, amount):
        self.__balance += amount

    def show_balance(self):
        print("Balance:", self.__balance)

b = Bank()
b.deposit(500)
b.show_balance()

# print(b.__balance)  # This will give error
# Out:
# Balance: 1500

# %%
class Dog:
    def sound(self):
        print("Dog barks")

class Cat:
    def sound(self):
        print("Cat meows")

for animal in (Dog(), Cat()):
    animal.sound()
# Out:
# Dog barks
# Cat meows

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, l, b):
        self.l = l
        self.b = b

    def area(self):
        return self.l * self.b

obj = Rectangle(5, 4)
print("Area:", obj.area())
# Out:
# Area: 20

# %%
class Number:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return self.value + other.value

n1 = Number(10)
n2 = Number(20)

print(n1 + n2)
# Out:
# 30
