# %% [markdown]
# <a href="https://colab.research.google.com/github/DigantaDantale/Python-Experiments-/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 10
Y = 20
# output: x + y = 30
print ( 'X + Y =', X + Y )
print ( 'X - Y =', X - Y )
print ( 'X * Y =', X * Y )
print ( 'X / Y =', X / Y )
print ( 'X % Y =', X % Y )
print('X // Y =',X//Y)
print ( 'X ** Y =', X ** Y )
# Out:
# X + Y = 30
# X - Y = -10
# X * Y = 200
# X / Y = 0.5
# X % Y = 10
# X // Y = 0
# X ** Y = 100000000000000000000

# %%
x = 20
y = 25
print('x == y is',x==y)
print('x != y is',x!=y)
print('x > y is',x>y)
print('x < y is',x<y)
print('x >= y is',x>=y)
print('x <= y is',x<=y)
# Out:
# x == y is False
# x != y is True
# x > y is False
# x < y is True
# x >= y is False
# x <= y is True

# %%
list_one = [1,2,3,4,5,6,7,8,9]

a = 5
b = 12

if (a in list_one):
    print( "a is presented in the list" )
else:
    print( "a is not presented in the list")

if (b in list_one):
    print( "b is presented in the list" )
else:
    print( "b is not presented in the list")

x = 23
y = 20
list_two = [10, 15, 20, 30, 35, 40, 45, 50]

if (x not in list_two):
    print("x is not available in the list" )
else:
    print( "x is available in the given list" )

if (y not in list_two):
    print( "y is not available in the given list" )
else:
    print( "y is available in the given list" )
# Out:
# a is presented in the list
# b is not presented in the list
# x is not available in the list
# y is available in the given list

# %%
x = 6
if (type(x) is int):
 print ("true")
else:
 print ("false")
x = 4.5
if (type (x) is not int) :
 print ("true")
else:
 print ("false")
# Out:
# true
# true
