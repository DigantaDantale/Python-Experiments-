# %% [markdown]
# <a href="https://colab.research.google.com/github/DigantaDantale/Python-Experiments-/blob/main/Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tuple with elements
numbers = (10, 20, 30, 40)
print("Numbers Tuple:", numbers)
# Mixed data tuple
mixed = (10, "Hello", 3.14, True)
print("Mixed Tuple:", mixed)
# Nested tuple
nested = (1, 2, (3, 4, 5))
print("Nested Tuple:", nested)
# Tuple without parentheses
implicit_tuple = 1, 2, 3, 4
print("Tuple without parentheses:", implicit_tuple)
# Out:
# Numbers Tuple: (10, 20, 30, 40)
# Mixed Tuple: (10, 'Hello', 3.14, True)
# Nested Tuple: (1, 2, (3, 4, 5))
# Tuple without parentheses: (1, 2, 3, 4)

# %%
# Concatenation
t1 = (1, 2, 3)
t2 = (4, 5, 6)
combined = t1 + t2
print("Concatenated Tuple:", combined)
# Repetition
repeated = t1 * 2
print("Repeated Tuple:", repeated)
# Out:
# Concatenated Tuple: (1, 2, 3, 4, 5, 6)
# Repeated Tuple: (1, 2, 3, 1, 2, 3)

# %%
# Membership
print("Is 2 in t1?", 2 in t1)
print("Is 10 not in t1?", 10 not in t1)
# Out:
# Is 2 in t1? True
# Is 10 not in t1? True

# %%
# Indexing
colors = ("red", "green", "blue", "yellow", "purple")
print("First element:", colors[0])
print("Third element:", colors[2])
print("Last element:", colors[-1])
# Out:
# First element: red
# Third element: blue
# Last element: purple

# %%
# Convert tuple to list
tuple_data = (1, 2, 3, 4)
list_data = list(tuple_data)
print("Tuple to List:", list_data)
# Out:
# Tuple to List: [1, 2, 3, 4]

# %%
# Convert tuple to list
tuple_data = (1, 2, 3, 4)
list_data = list(tuple_data)
print("Tuple to List:", list_data)
# Modify list
list_data.append(5)
print("Modified List:", list_data)
# Convert back to tuple
tuple_data = tuple(list_data)
print("List back to Tuple:", tuple_data)
print()
# Out:
# Tuple to List: [1, 2, 3, 4]
# Modified List: [1, 2, 3, 4, 5]
# List back to Tuple: (1, 2, 3, 4, 5)

# %%
# Program to find max and min manually
numbers = (15, 3, 8, 22, 5, 13)
max_val = numbers[0]
min_val = numbers[0]
for n in numbers:
    if n > max_val:
        max_val = n
    if n < min_val:
        min_val = n
print("Maximum:", max_val)
print("Minimum:", min_val)
# Out:
# Maximum: 22
# Minimum: 3

# %%
# Nested tuple example
data = (("Alice", 25), ("Bob", 30), ("Charlie", 28))
for name, age in data:
 print(f"Name: {name}, Age: {age}")
# Out:
# Name: Alice, Age: 25
# Name: Bob, Age: 30
# Name: Charlie, Age: 28

# %%
# Convert list of tuples into dictionary
pairs = [("a", 10), ("b", 20), ("c", 30)]
dictionary = dict(pairs)
print("Dictionary:", dictionary)
# Out:
# Dictionary: {'a': 10, 'b': 20, 'c': 30}

# %%
# Create a tuple of squares using generator :Tuple Comprehension
squares = tuple(x ** 2 for x in range(1, 6))
print("Squares Tuple:", squares)
# Out:
# Squares Tuple: (1, 4, 9, 16, 25)

# %%
# Count frequency of each element in tuple
t = (1, 2, 3, 2, 4, 1, 2)
frequency = {}
for item in t:
 frequency[item] = frequency.get(item, 0) + 1
print("Element Frequency:", frequency)
# Out:
# Element Frequency: {1: 2, 2: 3, 3: 1, 4: 1}

# %%
# Tuple unpacking and swapping variables
a, b = 10, 20
print("Before swapping:", a, b)
# Swapping using tuple
a, b = b, a
print("After swapping:", a, b)
# Out:
# Before swapping: 10 20
# After swapping: 20 10

# %%
# Slicing
print("Colors[0:3]:", colors[0:3])
print("Colors[2:]:", colors[2:])
print("Colors[:4]:", colors[:4])
print("Colors[-3:]:", colors[-3:])
print()
nums = (15, 8, 22, 5, 13, 30)
print("Tuple:", nums)
print("Length:", len(nums))
print("Maximum:", max(nums))
print("Minimum:", min(nums))
print("Sum:", sum(nums))
print("Sorted (as list):", sorted(nums))
print()
# Out:
# Colors[0:3]: ('red', 'green', 'blue')
# Colors[2:]: ('blue', 'yellow', 'purple')
# Colors[:4]: ('red', 'green', 'blue', 'yellow')
# Colors[-3:]: ('blue', 'yellow', 'purple')
#
# Tuple: (15, 8, 22, 5, 13, 30)
# Length: 6
# Maximum: 30
# Minimum: 5
# Sum: 93
# Sorted (as list): [5, 8, 13, 15, 22, 30]
